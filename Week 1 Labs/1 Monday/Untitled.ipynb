# %%
import numpy as np
import pandas as pd
import scipy.stats
import matplotlib.pyplot as plt
# %matplotlib inline

# %%
x = np.arange(0,10)
y = x*x

# %%
plt.plot(x,y)
plt.title('y=x^2')
plt.xlabel('x')
plt.ylabel('y')
plt.show()
