# %% [markdown]
# <div>
# <img src=https://www.institutedata.com/wp-content/uploads/2019/10/iod_h_tp_primary_c.svg width="300">
# </div>

# %% [markdown]
# ## Lab 4.2.1: Feature Selection

# %% [markdown]
# ### 1. Load & Explore Data

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %matplotlib inline

# %% [markdown]
# #### 1.1 Load Data

# %%
# Read CSV
wine_csv = pd.read_csv('../../../DATA/winequality_merged.csv')

# %% [markdown]
# #### 1.2 Explore Data (Exploratory Data Analysis)

# %%
# ANSWER
wine_csv.head(10)
# Out:
#    fixed acidity  volatile acidity  citric acid  residual sugar  chlorides  \
# 0            7.4              0.70         0.00             1.9      0.076
# 1            7.8              0.88         0.00             2.6      0.098
# 2            7.8              0.76         0.04             2.3      0.092
# 3           11.2              0.28         0.56             1.9      0.075
# 4            7.4              0.70         0.00             1.9      0.076
# 5            7.4              0.66         0.00             1.8      0.075
# 6            7.9              0.60         0.06             1.6      0.069
# 7            7.3              0.65         0.00             1.2      0.065
# 8            7.8              0.58         0.02             2.0      0.073
# 9            7.5              0.50         0.36             6.1      0.071
#
#    free sulfur dioxide  total sulfur dioxide  density    pH  sulphates  \
# ...

# %%
wine_csv.shape
# Out:
# (6497, 13)

# %%
wine_csv.columns
# Out:
# Index(['fixed acidity', 'volatile acidity', 'citric acid', 'residual sugar',
#        'chlorides', 'free sulfur dioxide', 'total sulfur dioxide', 'density',
#        'pH', 'sulphates', 'alcohol', 'quality', 'red_wine'],
#       dtype='object')

# %%
wine_csv.dtypes
# Out:
# fixed acidity           float64
# volatile acidity        float64
# citric acid             float64
# residual sugar          float64
# chlorides               float64
# free sulfur dioxide     float64
# total sulfur dioxide    float64
# density                 float64
# pH                      float64
# sulphates               float64
# alcohol                 float64
# quality                   int64
# red_wine                  int64
# dtype: object

# %%
wine_csv.describe()
# Out:
#        fixed acidity  volatile acidity  citric acid  residual sugar  \
# count    6497.000000       6497.000000  6497.000000     6497.000000
# mean        7.215307          0.339666     0.318633        5.443235
# std         1.296434          0.164636     0.145318        4.757804
# min         3.800000          0.080000     0.000000        0.600000
# 25%         6.400000          0.230000     0.250000        1.800000
# 50%         7.000000          0.290000     0.310000        3.000000
# 75%         7.700000          0.400000     0.390000        8.100000
# max        15.900000          1.580000     1.660000       65.800000
#
#          chlorides  free sulfur dioxide  total sulfur dioxide      density  \
# count  6497.000000          6497.000000           6497.000000  6497.000000
# mean      0.056034            30.525319            115.744574     0.994697
# std       0.035034            17.749400             56.521855     0.002999
# ...

# %%
sns.distplot(wine_csv['fixed acidity'])

# %%
sns.distplot(wine_csv['volatile acidity'])

# %%
sns.distplot(wine_csv['citric acid'])

# %%
sns.distplot(wine_csv['residual sugar'])

# %%
sns.distplot(wine_csv['chlorides'])

# %%
sns.distplot(wine_csv['free sulfur dioxide'])

# %%
sns.distplot(wine_csv['density'])

# %%
sns.distplot(wine_csv['pH'])

# %%
sns.distplot(wine_csv['sulphates'])

# %%
sns.distplot(wine_csv['alcohol'])

# %%
wine_csv['quality'].value_counts().sort_index().plot(kind='bar')

# %%
wine_csv['red_wine'].value_counts().plot(kind='bar')

# %%
wine_csv.corr()
# Out:
#                       fixed acidity  volatile acidity  citric acid  \
# fixed acidity              1.000000          0.219008     0.324436
# volatile acidity           0.219008          1.000000    -0.377981
# citric acid                0.324436         -0.377981     1.000000
# residual sugar            -0.111981         -0.196011     0.142451
# chlorides                  0.298195          0.377124     0.038998
# free sulfur dioxide       -0.282735         -0.352557     0.133126
# total sulfur dioxide      -0.329054         -0.414476     0.195242
# density                    0.458910          0.271296     0.096154
# pH                        -0.252700          0.261454    -0.329808
# sulphates                  0.299568          0.225984     0.056197
# alcohol                   -0.095452         -0.037640    -0.010493
# quality                   -0.076743         -0.265699     0.085532
# red_wine                   0.486740          0.653036    -0.187397
#
# ...

# %%
# isolate correlations  with target variable, quality.
wine_csv.corr()[['quality']].sort_values(by='quality', ascending = False)
# Out:
#                        quality
# quality               1.000000
# alcohol               0.444319
# citric acid           0.085532
# free sulfur dioxide   0.055463
# sulphates             0.038485
# pH                    0.019506
# residual sugar       -0.036980
# total sulfur dioxide -0.041385
# fixed acidity        -0.076743
# red_wine             -0.119323
# chlorides            -0.200666
# volatile acidity     -0.265699
# density              -0.305858

# %%
#isolate variables with higher correlation to quality in pairplot
sns.pairplot(wine_csv[['quality','alcohol', 'chlorides', 'volatile acidity', 'density']])

# %%
#check for nulls
wine_csv.isnull().sum()
# Out:
# fixed acidity           0
# volatile acidity        0
# citric acid             0
# residual sugar          0
# chlorides               0
# free sulfur dioxide     0
# total sulfur dioxide    0
# density                 0
# pH                      0
# sulphates               0
# alcohol                 0
# quality                 0
# red_wine                0
# dtype: int64

# %% [markdown]
# ### 2. Set Target Variable

# %% [markdown]
# Create a target variable for wine quality.

# %%
# Target Variable
y = wine_csv['quality']

# %% [markdown]
# ### 3. Set Predictor Variables

# %% [markdown]
# Create a predictor matrix with variables of your choice. State your reason.

# %%
# ANSWER: based on highest correlations with quality
X = wine_csv[['alcohol', 'chlorides', 'volatile acidity', 'density']]

# %% [markdown]
# ### 4. Using Linear Regression Create a Model and Test Score

# %%
from sklearn.linear_model import LinearRegression
from sklearn.model_selection import train_test_split

# %%
# Train-Test Split

X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.20, random_state=42)

# %%
# Create a model for Linear Regression
linreg=LinearRegression()

# Fit the model with the Training data
linreg.fit(X_train, y_train)
print(linreg.coef_, linreg.intercept_)

# Calculate the score (R^2 for Regression) for Training Data
print(linreg.score(X_train, y_train))

# Calculate the score (R^2 for Regression) for Testing Data
print(linreg.score(X_test, y_test))
# Out:
# [ 0.39187742 -0.08243747 -1.51250401 40.83297487] -38.39531946161832
# 0.2707886547599645
# 0.25213547513049606

# %% [markdown]
# ### BONUS: Cross validation

# %%
# Cross validation 
from sklearn.model_selection import KFold 
from sklearn.metrics import mean_squared_error

# %%
# Set up 5-fold cross validation  
k_fold = KFold(5, shuffle=True)
train_scores = []
train_rmse = []
test_scores = []
test_rmse = []

for k, (train, test) in enumerate(k_fold.split(X)):
    
    # Get training and test sets for X and y
    
    # Fit model with training set
    
    # Make predictions with training and test set
    
    # Score R2 and RMSE on training and test sets and store in list
    
# Create a metrics_df dataframe to display r2 and rmse scores

# %%
# Describe the metrics

# %% [markdown]
# ### 5. Feature Selection
#
# What's your score (R^2 for Regression) for Testing Data?
#
# How many feature have you selected? Can you improve your score by selecting different features?

# %% [markdown]
# **Please continue with Lab 4.2.2 with the same dataset.**

# %% [markdown]
# ---
#
#
#
# ---
#
#
#
# > > > > > > > > > © 2019 Institute of Data
#
#
# ---
#
#
#
# ---
